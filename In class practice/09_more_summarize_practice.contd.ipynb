# %%
library('tidyverse')
library('patchwork')
library('nycflights13')
options(repr.plot.width = 8, repr.plot.height = 4, repr.plot.res = 300)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Use filter to make a table with just flights weather data from January.

# %%
weather |> head()
# Out:
#   origin year month day hour temp  dewp  humid wind_dir wind_speed wind_gust
# 1 EWR    2013 1     1   1    39.02 26.06 59.37 270      10.35702   NA
# 2 EWR    2013 1     1   2    39.02 26.96 61.63 250       8.05546   NA
# 3 EWR    2013 1     1   3    39.02 28.04 64.43 240      11.50780   NA
# 4 EWR    2013 1     1   4    39.92 28.04 62.21 250      12.65858   NA
# 5 EWR    2013 1     1   5    39.02 28.04 64.43 260      12.65858   NA
# 6 EWR    2013 1     1   6    37.94 28.04 67.21 240      11.50780   NA
#   precip pressure visib time_hour
# 1 0      1012.0   10    2013-01-01 01:00:00
# 2 0      1012.3   10    2013-01-01 02:00:00
# 3 0      1012.5   10    2013-01-01 03:00:00
# 4 0      1012.2   10    2013-01-01 04:00:00
# 5 0      1011.9   10    2013-01-01 05:00:00
# 6 0      1012.4   10    2013-01-01 06:00:00

# %% [markdown]
# Do the same for June.

# %%
median_june  = weather |> 
    group_by(month) |>
    filter(month == 6) |> 
    summarize(median.temp = median(temp))

median_january
# Out:
#   month median.temp
# 1 1     37.04

# %% [markdown]
# Use `filter` and `summarize` to produce two single row tables. One that has the median `temp` for January, and one that has the median `temp` for June.

# %%
# geom_hline(data = median_january, mapping = aes(yintercept = ))

# %%
make_month_plot = function(month_to_plot = 1){ #initialized it to 1
    #change to 6 for june chart

    month_weather = weather |> filter(month==month_to_plot)

    median_for_month  = weather |> 
        group_by(month) |>
        filter(month == month_to_plot) |> 
        summarize(median.temp = median(temp))
#optional data= and mapping=
    w = ggplot(month_weather, aes(x=day, y=temp, color=hour)) +
        geom_point(position=position_jitter(height=0, width=0.3),size=1) +
        scale_color_viridis_c() +
        geom_hline(data=median_for_month, mapping=aes(yintercept=median.temp)) +
        ylim(c(0, 100)) 
    

    w
}

# %%
w_june = make_month_plot(6)
w_jan = make_month_plot(1)

w_jan + w_june + plot_layout(guides = 'collect')
# Out:
# plot without title

# %%
#function example
add_two_numbers = function(a,b) {
    print(a)
    a+b
}

# %%
add_two_numbers(1,2)

#override position of the arguments
add_two_numbers(b=1,a=2)

#why do we have the [1]? this means that its the first number in a series of values
# Out:
# [1] 1
# [1] 3
# [1] 2
# [1] 3

# %%
median_jan  = weather |> 
    group_by(month) |>
    filter(month == 1) |> 
    summarize(median.temp = median(temp))

median_january

# %%
jan_weather = weather |>
    filter(month == 1)

jan_weather |> head()
# Out:
#   origin year month day hour temp  dewp  humid wind_dir wind_speed wind_gust
# 1 EWR    2013 1     1   1    39.02 26.06 59.37 270      10.35702   NA
# 2 EWR    2013 1     1   2    39.02 26.96 61.63 250       8.05546   NA
# 3 EWR    2013 1     1   3    39.02 28.04 64.43 240      11.50780   NA
# 4 EWR    2013 1     1   4    39.92 28.04 62.21 250      12.65858   NA
# 5 EWR    2013 1     1   5    39.02 28.04 64.43 260      12.65858   NA
# 6 EWR    2013 1     1   6    37.94 28.04 67.21 240      11.50780   NA
#   precip pressure visib time_hour
# 1 0      1012.0   10    2013-01-01 01:00:00
# 2 0      1012.3   10    2013-01-01 02:00:00
# 3 0      1012.5   10    2013-01-01 03:00:00
# 4 0      1012.2   10    2013-01-01 04:00:00
# 5 0      1011.9   10    2013-01-01 05:00:00
# 6 0      1012.4   10    2013-01-01 06:00:00

# %%
june_weather = weather |>
    filter(month == 6)

june_weather |> head()
# Out:
#   origin year month day hour temp  dewp  humid wind_dir wind_speed wind_gust
# 1 EWR    2013 6     1   0    78.08 64.04 62.05 230      6.90468    NA
# 2 EWR    2013 6     1   1    77.00 64.94 66.36 230      8.05546    NA
# 3 EWR    2013 6     1   2    75.92 66.02 71.42 230      6.90468    NA
# 4 EWR    2013 6     1   3    73.94 66.02 76.31 230      5.75390    NA
# 5 EWR    2013 6     1   4    73.04 66.02 78.65 220      5.75390    NA
# 6 EWR    2013 6     1   5    71.96 66.02 81.57 190      5.75390    NA
#   precip pressure visib time_hour
# 1 0      1016.4   10    2013-06-01 00:00:00
# 2 0      1016.2   10    2013-06-01 01:00:00
# 3 0      1016.0   10    2013-06-01 02:00:00
# 4 0      1015.8   10    2013-06-01 03:00:00
# 5 0      1016.1   10    2013-06-01 04:00:00
# 6 0      1016.0   10    2013-06-01 05:00:00

# %% [markdown]
# Re-create the following figure.

# %% [markdown]
# <img src="./example.png" style="width: 800px;" />

# %% [markdown]
# - Use `geom_hline` for the median line.
# - Use `scale_color_viridis_c` to set the color scale.
# - This chart can be made by facetting or each plot can be created by itself and combined with `patchwork`. For this example use `patchwork`.
# - Use `ylim` to make the y-axis for each plot the same.

# %%
p = ggplot(jan_weather, aes(x = day, y = temp, color = hour)) +
    geom_point(position = position_jitter(height = 0, width = 0.2)) + 
    scale_color_viridis_c() + 
    geom_hline(data = median_january, mapping = aes(yintercept = median.temp))

p
# Out:
# plot without title

# %%
q = ggplot(june_weather, aes(x = day, y = temp, color = hour)) +
    geom_point(position = position_jitter(height = 0, width = 0.2)) + 
    scale_color_viridis_c() + 
    geom_hline(data = median_january, mapping = aes(yintercept = median.temp))

q
# Out:
# plot without title

# %%
geom_hline

# %%
s = ggplot(jan_weather, aes(x=day, y=temp, color=hour)) + 
    geom_point(position=position_jitter(height=0, width=0.2)) + 
    #ylim(c(0, 100)) +
    scale_color_viridis_c() +
    geom_hline(data=median_january, mapping=aes(yintercept=median.temp))

t = ggplot(june_weather, aes(x=day, y=temp, color=hour)) + 
     geom_point(position=position_jitter(height=0, width=0.2)) + 
   # ylim(c(0, 100)) +
    scale_color_viridis_c() +
    geom_hline(data=median_june, mapping=aes(yintercept=median.temp))

s + t
# Out:
# plot without title

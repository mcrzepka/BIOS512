# %% [markdown]
# # Distributions

# %% [markdown]
# - central tendency

# %% [markdown]
# - range for most the data

# %% [markdown]
# - bounds

# %%
library('tidyverse')
options(repr.plot.width=4, repr.plot.height=3)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df = mpg %>%
    group_by(class) %>%
    summarize(mean_hwy = mean(hwy), sd_hwy = sd(hwy))

p = ggplot(df, aes(x = class))

p = p + geom_bar(aes(y = mean_hwy), stat = 'identity')

p = p + geom_errorbar(aes(ymin = mean_hwy + sd_hwy, ymax = mean_hwy - sd_hwy),
                      color = 'red', width = 0.2)

p = p + theme(axis.text.x = element_text(angle = 45, hjust = 1))

p
# Out:
# plot without title

# %% [markdown]
# - no lower (or upper) bound
# - chart must include zero
# - not clear what the range represents

# %% [markdown]
# # Boxplot

# %% [markdown]
# - what do you think the geom for boxplots is called?

# %%
# ?geom_boxplot

# %%
p
# Out:
# plot without title

# %%
mpg %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
p = ggplot(mpg, aes(x = class, y = hwy))
p = p + geom_boxplot()
p
# Out:
# plot without title

# %% [markdown]
# - central tendency?
# - range for most the data?
# - bounds?

# %%
mpg.sorted = mpg %>%
    mutate(class.sorted = fct_reorder(class, hwy))

p = ggplot(mpg.sorted, aes(x = class.sorted, y = hwy))

p = p + geom_boxplot()

p = p + theme(axis.text.x = element_text(angle = 45, hjust = 1))

p
# Out:
# plot without title

# %%
p = ggplot(mpg.sorted, aes(x = class.sorted, y = hwy))

p = p + geom_boxplot(fill = NA, outlier.shape = NA, color = '#003366', fatten = 1, lwd = 0.25)

p = p + geom_point(position = position_jitter(h = 0, w = 0.15), size = 0.75, alpha = 0.5)

p = p + theme_bw()

p = p + theme(panel.border = element_blank())

p = p + labs(x = 'class', y = 'highway miles per gallon')

p = p + coord_flip()

p
# Out:
# plot without title

# %% [markdown]
# # Histograms

# %% [markdown]
# - what do you think the geom is named for histograms?

# %%
diamonds %>% head
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# We want to see the range of price...

# %%
p = ggplot(diamonds, aes(x = price))

p = p + geom_histogram(binwidth=100)
# can choose bins or r can choose for you by default with no argument (ex: bins=10)
p
# Out:
# plot without title

# %% [markdown]
# - adjust with `bins` and `binwidth` argument.

# %% [markdown]
# # KDE

# %% [markdown]
# - what do you think the geom is named for KDE plots (this one is not as clear)?

# %%
p = ggplot(diamonds, aes(x = price, fill=cut))

p = p + geom_density(alpha=0.2)

#argument example for geom_density: fill='firebrick', color='firebrick'
p

#curve of the sum of all the normal distributions, matches shape of histogram
# Out:
# plot without title

# %% [markdown]
# - add `fill` with alpha

# %% [markdown]
# # Rugs

# %% [markdown]
# - Can help us include all values and see bounds.
# - Not great with large number of points but you can adjust alpha.

# %%
p = ggplot(mtcars, aes(x = wt))

#p = p + geom_histogram(bins = 20)
p = p + geom_density(bins = 20, fill='steelblue', alpha=0.2) + geom_rug()
p
# Out:
# Warning message:
# “Ignoring unknown parameters: bins”
# plot without title

# %%
p + geom_rug()
#adds tickmark along x axis for each data point that is being used to create histogram
# Out:
# plot without title

# %% [markdown]
# # ECDF next lecture
#
# - https://ericmjl.github.io/blog/2018/7/14/ecdfs/
